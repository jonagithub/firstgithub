# %%
#immport library
import seaborn
#canvas (Baloon board)
seaborn.set(style='whitegrid')

#load dataset
kashti = seaborn.load_dataset("titanic")

seaborn.boxplot(x="class", y="fare", data=kashti)
# Out:
# <AxesSubplot:xlabel='class', ylabel='fare'>

# %%
#immport library
import seaborn
#canvas (Baloon board)
seaborn.set(style='whitegrid')

#load dataset
tip = seaborn.load_dataset("tips")
tip

seaborn.boxplot(x="day", y="tip", data=tip, saturation=1)
# Out:
# <AxesSubplot:xlabel='day', ylabel='tip'>

# %%
#import library
import seaborn as sns
import pandas as pd
import numpy as np

#load dataset
tip = seaborn.load_dataset("tips")
tip
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tip.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
#immport library
import seaborn as sns
#canvas (Baloon board)
seaborn.set(style='whitegrid')

#load dataset
tip = seaborn.load_dataset("tips")


seaborn.boxplot(x=tip['total_bill'])

# each box plot
# Out:
# <AxesSubplot:xlabel='total_bill'>

# %%
#immport library
import seaborn as sns
#canvas (Baloon board)
seaborn.set(style='whitegrid')

#load dataset
tip = seaborn.load_dataset("tips")


seaborn.boxplot(x=tip['tip'])

# each box plot
# Out:
# <AxesSubplot:xlabel='tip'>

# %%
#immport library
import seaborn as sns
#canvas (Baloon board)
sns.set(style='whitegrid')

#load dataset
tip = sns.load_dataset("tips")

sns.boxplot(x="tip", y="day", hue="smoker", data=tip,
           palette="Set2", dodge=True) #dodge means side by side
# Out:
# <AxesSubplot:xlabel='tip', ylabel='day'>

# %%
#immport library
import seaborn as sns
#canvas (Baloon board)
sns.set(style='whitegrid')

#load dataset
tip = sns.load_dataset("tips")

sns.boxplot(x="tip", y="day", hue="smoker", data=tip,
           palette="Set2", dodge=False) #dodge False means behind or front
# Out:
# <AxesSubplot:xlabel='tip', ylabel='day'>

# %%
#immport library
import seaborn as sns
#canvas (Baloon board)
seaborn.set(style='whitegrid')

#load dataset
tip = sns.load_dataset("tips")
tip

sns.boxplot(x="day", y="tip", data=tip, saturation=1, orient='h')
# Out:
# <AxesSubplot:xlabel='day', ylabel='tip'>

# %% [markdown]
# # How to manage individual colors for each hue color
#
# - palette = {"Yes": "red", "No":"green"}
# - sns.boxplot(x="day", y="total_bill", hue="smoker", data=tips,  palette=palette)
#
# - OR
# - sns.boxplot(x="day", y="total_bill", hue="smoker",
#                  data=tip, palette=["green","red"])

# %%
#immport library
import seaborn as sns
#canvas (Baloon board)
seaborn.set(style='whitegrid')

#load dataset
tip = sns.load_dataset("tips")
tip


palette ={"Yes": "red", "No": "green"}

sns.boxplot(x="day", y="total_bill", hue="smoker",
                 data=tip, palette=palette)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
#immport library
import seaborn as sns
#canvas (Baloon board)
seaborn.set(style='whitegrid')

#load dataset
tip = sns.load_dataset("tips")
tip

sns.boxplot(x="day", y="total_bill", hue="smoker",
                 data=tip, palette=["green","red"])
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
import seaborn as sns
import pandas as pd
import numpy as np

kashti = sns.load_dataset("titanic")
kashti.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.boxplot(x="sex", y="fare", data=kashti)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='fare'>

# %%
import seaborn as sns
import pandas as pd
import numpy as np


kashti = sns.load_dataset("titanic")
sns.boxplot(x="survived", y="age", data=kashti)
# Out:
# <AxesSubplot:xlabel='survived', ylabel='age'>

# %%
import seaborn as sns
import pandas as pd
import numpy as np



sns.boxplot(x="survived", y="age", showmeans=True, data=kashti)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-f37507ca6dc0> in <module>
#       5
#       6
# ----> 7 sns.boxplot(x="survived", y="age", showmean=True, data=kashti)
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in boxplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth, whis, ax, **kwargs)
#    2236     kwargs.update(dict(whis=whis))
#    2237
# -> 2238     plotter.plot(ax, kwargs)
#    2239     return ax
#    2240
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in plot(self, ax, boxplot_kws)
# ...

# %%
sns.boxplot(x="survived", y="age", shhowmdata=kashti)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-f13e0d609cbb> in <module>
# ----> 1 sns.boxplot(x="survived", y="age", shhowmdata=kashti)
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in boxplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth, whis, ax, **kwargs)
#    2228 ):
#    2229
# -> 2230     plotter = _BoxPlotter(x, y, hue, data, order, hue_order,
#    2231                           orient, color, palette, saturation,
#    2232                           width, dodge, fliersize, linewidth)
#
# ...

# %%
import seaborn as sns
import pandas as pd
import numpy as np



sns.boxplot(x="survived", y="age", showmeans=True, data=kashti)
# Out:
# <AxesSubplot:xlabel='survived', ylabel='age'>

# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

kashti = sns.load_dataset("titanic")
sns.boxplot(x="survived", y="age", showmeans=True,
            meanprops = {"marker": "*",
                        "markersize": "12",
                        "markeredgecolor": "red"},
            data=kashti)
plt.xlabel("How many survived", size=14, weight='bold'),
plt.ylabel("Age (years)", size=12, weight='bold'),
plt.title("Box plot of survivors and age in years", size=14, weight='bold')
plt.show()

# %% [markdown]
# # Facet Wrap and Facet Grid
#
# - facet_wrap is mostly used for the single variable for which it gives you a  2nd panel
#
# - facet_grid is used for two variable with which it akes a 2nd grid of panels using rows and colummns

# %% [markdown]
# # Examples taken from seaborn website
# - https://seaborn.pydata.org/examples/index.html

# %%
import seaborn as sns
sns.set_theme(style="whitegrid")

# Load the brain networks dataset, select subset, and collapse the multi-index
df = sns.load_dataset("brain_networks", header=[0, 1, 2], index_col=0)

used_networks = [1, 5, 6, 7, 8, 12, 13, 17]
used_columns = (df.columns
                  .get_level_values("network")
                  .astype(int)
                  .isin(used_networks))
df = df.loc[:, used_columns]

df.columns = df.columns.map("-".join)

# Compute a correlation matrix and convert to long-form
corr_mat = df.corr().stack().reset_index(name="correlation")

# Draw each cell as a scatter point with varying size and color
g = sns.relplot(
    data=corr_mat,
    x="level_0", y="level_1", hue="correlation", size="correlation",
    palette="vlag", hue_norm=(-1, 1), edgecolor=".7",
    height=10, sizes=(50, 250), size_norm=(-.2, .8),
)

# Tweak the figure to finalize
g.set(xlabel="", ylabel="", aspect="equal")
g.despine(left=True, bottom=True)
g.ax.margins(.02)
for label in g.ax.get_xticklabels():
    label.set_rotation(90)
for artist in g.legend.legendHandles:
    artist.set_edgecolor(".7")
